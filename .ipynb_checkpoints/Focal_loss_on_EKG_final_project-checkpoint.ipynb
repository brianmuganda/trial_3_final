# %% [markdown]
# Import Packages

# %%
# for numerical analysis
import numpy as np # linear algebra

# to store and process in a dataframe
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Visualizations, for ploting graphs
import matplotlib.pyplot as plt

# image processing
import matplotlib.image as mpimg

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# advanced ploting
import seaborn as sns
# PyTorch
import torchvision
from torchvision import transforms, datasets, models

import torch
from torch import optim, cuda
from torch.utils.data import DataLoader, sampler
from torch.autograd import Variable

import torch.nn as nn
import torch.nn.functional as F

from torch.nn import Linear, ReLU, CrossEntropyLoss, Sequential, Conv2d, MaxPool2d
from torch.nn import Module, Softmax, BatchNorm2d, Dropout

import gc

import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# Image manipulations
from PIL import Image
#from libjpeg import decode

import cv2

# Timing utility
from timeit import default_timer as timer

from IPython.core.interactiveshell import InteractiveShell

# Printing out all outputs
InteractiveShell.ast_node_interactivity = 'all'

# file operations

import shutil
import os
from os import walk

# to list files
import glob

print(os.listdir("ECG_data/"))

# current working directory
folder_path = os.listdir("ECG_data/")
folder_path

#class_folders= os.listdir(folder_path)
#class_folders

#for class_folder in class_folders:
#   class_path= os.path.join(folder_path, class_folder)
#   num_images = len(os.listdir(class_path))
#    print(f'Number of images in {class_folder}:{num_images}')

# no. of files

def list_files(startpath):
    
    for root, dirs, files in os.walk(startpath):
        
        level = root.replace(startpath, '').count(os.sep)
        
        indent = ' ' * 4 * (level)
        
        print('{}{}'.format(indent, os.path.basename(root)), '-', len(os.listdir(root)))
        
folder = 'ECG_data/'
list_files(folder)

folder = 'ECG_data/'
list_files(folder)

# list of files in the dataset /input/ecg-images/MITBIH_img

os.listdir('ECG_data/test/')

# Classes in the data

ECG_list = os.listdir('ECG_data/test/')

n_classes = len(ECG_list)

print(f'There are {n_classes} different classes.')

ECG_list

classes = ('S', 'V', 'Q', 'N', 'F', 'M')

#Count Number of Files in the MITBIH_img Folder

N_imgs = os.listdir('ECG_data/test/N/')
print('# of Normal beats: ',len(N_imgs))

F_imgs = os.listdir('ECG_data/test/F/')
print('# of Fusion beats: ',len(F_imgs))

Q_imgs = os.listdir('ECG_data/test/Q/')
print('# of Unknown beats: ',len(Q_imgs))

V_imgs = os.listdir('ECG_data/test/V/')
print('# of Ventricular ectopic beats: ',len(V_imgs))

S_imgs = os.listdir('ECG_data/test/S/')
print('# of Supraventricular ectopic beats: ',len(S_imgs))

M_imgs = os.listdir('ECG_data/test/M/')
print('# of M-Research ectopic beats: ',len(M_imgs))

#print(N_dir)
print(N_imgs[0])

#EDA

def imshow(image):
    """Display image"""
    plt.figure(figsize=(6, 6))
    plt.imshow(image)
    plt.axis('off')
    plt.show()
    
image = mpimg.imread(os.path.join('ECG_data/test/N/', N_imgs[0]))

imshow(image)

print(image.shape)
print(type(image))

#Show Images From Each Folder

# Define a function which will plot several images

def image_shows(folder, number_of_images):
    
    n=number_of_images;
    
    folder_list = os.listdir(folder)
    
    fig, axes = plt.subplots(nrows = 1, ncols=n, figsize=(20, 10))
    
    for i in range(n):
        
        print(os.path.join(folder, folder_list[i]))
        
        image = mpimg.imread(os.path.join(folder, folder_list[i]));
        
        axes[i].imshow(image);
        
# Examples of N

image_shows(folder = 'ECG_data/test/N/', number_of_images = 6)

# Examples of S

image_shows(folder = 'ECG_data/test/S/', number_of_images = 6)

# Examples of Q

image_shows(folder = 'ECG_data/test/Q/', number_of_images = 6)

# Examples of M

image_shows(folder = 'ECG_data/test/M/', number_of_images = 6)

# Examples of V

image_shows(folder = 'ECG_data/test/V/', number_of_images = 6)

# Examples of F

image_shows(folder = 'ECG_data/test/F/', number_of_images = 6)

#To see 3 channels I plot figures with cv 2 package

#import cv2
import cv2
import numpy as np

print("OpenCV version:", cv2.__version__)
print("NumPy version:", np.__version__)

import cv2

imgcv = cv2.imread(os.path.join('ECG_data/test/N/', N_imgs[0]))
plt.imshow(imgcv)
plt.show();

imgcv.shape

b = imgcv.copy()
# set green and red channels to 0
b[:, :, 1] = 0
b[:, :, 2] = 0


g = imgcv.copy()
# set blue and red channels to 0
g[:, :, 0] = 0
g[:, :, 2] = 0

r = imgcv.copy()
# set blue and green channels to 0
r[:, :, 0] = 0
r[:, :, 1] = 0

#plot rgb
# plot data

fig = plt.figure(figsize=(15,15))

plot_1 = plt.subplot(131)
plot_1.imshow(r);

#plt.subplot(131).imshow(b);

plot_2 = plt.subplot(132, sharex=plot_1, sharey=plot_1)
plt.setp(plot_2.get_yticklabels(), visible=False);
plot_2.imshow(b);

plot_3 = plt.subplot(133, sharex=plot_1, sharey=plot_1)
plt.setp(plot_3.get_yticklabels(), visible=False);
plot_3.imshow(g);

plt.show();

for root, dirs, files in os.walk('ECG_data/'):
    print(root)
    #So, as the code runs, it will print the paths of all directories
    #within the '/ecg/' directory and its subdirectories.
    
folder = 'ECG_data/'
list_files(folder)

N_imgs       = len(os.listdir('ECG_data/train/N/'))
N_train_imgs = len(os.listdir('ECG_data/train/N/'))
N_test_imgs  = len(os.listdir('ECG_data/test/N/'))
print('number of N images at the original file: ', N_imgs)
print('total number of train and test picts:    ', N_train_imgs + N_test_imgs)

S_imgs       = len(os.listdir('ECG_data/train/S/'))
S_train_imgs = len(os.listdir('ECG_data/train/S/'))
S_test_imgs  = len(os.listdir('ECG_data/test/S/'))
print('number of S images at the original file: ', S_imgs)
print('total number of train and test picts:    ', S_train_imgs + S_test_imgs)

F_imgs       = len(os.listdir('ECG_data/train/F/'))
F_train_imgs = len(os.listdir('ECG_data/train/F/'))
F_test_imgs  = len(os.listdir('ECG_data/test/F/'))
print('number of F images at the original file: ', F_imgs)
print('total number of train and test picts:    ', F_train_imgs + F_test_imgs)

V_imgs       = len(os.listdir('ECG_data/train/V/'))
V_train_imgs = len(os.listdir('ECG_data/train/V/'))
V_test_imgs  = len(os.listdir('ECG_data/test/V/'))
print('number of V images at the original file: ', V_imgs)
print('total number of train and test picts:    ', V_train_imgs + V_test_imgs)

M_imgs       = len(os.listdir('ECG_data/train/M/'))
M_train_imgs = len(os.listdir('ECG_data/train/M/'))
M_test_imgs  = len(os.listdir('ECG_data/test/M/'))
print('number of M images at the original file: ', M_imgs)
print('total number of train and test picts:    ', M_train_imgs + M_test_imgs)

Q_imgs       = len(os.listdir('ECG_data/train/Q/'))
Q_train_imgs = len(os.listdir('ECG_data/train/Q/'))
Q_test_imgs  = len(os.listdir('ECG_data/test/Q/'))
print('number of Q images at the original file: ', Q_imgs)
print('total number of train and test picts:    ', Q_train_imgs + Q_test_imgs)

#Lets load images with datasets.ImageFolder function and than read and plot
#Set Data Loader
TRAIN_PATH        = 'ECG_data/train/'

transform         = transforms.Compose(
                                       [transforms.Resize([120,120]),
                                        transforms.Grayscale(), 
                                        transforms.ToTensor(),
                                        transforms.Normalize((0.5), (0.5))
                                       ])
  
train_data_set    = datasets.ImageFolder(root=TRAIN_PATH, transform=transform)

batch_size=32

train_data_loader = DataLoader(train_data_set, batch_size=batch_size, shuffle=True)


TEST_PATH        = 'ECG_data/test/'
  
test_data_set    = datasets.ImageFolder(root=TEST_PATH, transform=transform)

test_data_loader = DataLoader(test_data_set, batch_size=batch_size, shuffle=True)

# Run this to test your data loader

images, labels = next(iter(train_data_loader))

print(type(images))


print(images.size())

print("")
print("Batch Size:   ",images.size()[0])
print("Channel Size: ",images.size()[1])
print("Image Height: ",images.size()[2])
print("Image Width:  ",images.size()[3])

#The batch size is 32, image size is reduced to 120*120 and we need only one channel(Gray Scale).

def imshow_tensor(image, ax=None, title=None, normalize=True):
    
    """Imshow for Tensor."""
    
    if ax is None:
        fig, ax = plt.subplots()
        
    image = image.numpy().transpose((1, 2, 0))

    if normalize:
        mean = np.array([0.5])
        std = np.array([0.5])
        image = std * image + mean
        image = np.clip(image, 0, 1)

    ax.imshow(image)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    
    ax.tick_params(axis='both', length=0)
    ax.set_xticklabels('')
    ax.set_yticklabels('')

    return ax

#Plot one Batch of Files from Dataloader

# show images

ncol = 8;

imshow_tensor(torchvision.utils.make_grid(images,nrow = ncol));

# print labels

classes = ('N', 'Q', 'F', 'S', 'V','M')

nrow = batch_size/ncol;

for row in range(int(nrow)):
    
    print(' '.join('%5s' % classes[labels[(row*ncol)+j]] for j in range(ncol)))
    
#Building Convolutional Neural Networks

#First CNN Model

# CNN Architect
#Enhanced convolutional Neural Netwwork

#class EnhancedConvNet(nn.Module):
    
    #def __init__(self):
        #first convolution Block
        
       # super(EnhancedConvNet, self).__init__()

        #self.conv1  = nn.Conv2d(in_channels=1, out_channels=8, kernel_size=3, stride=1, padding=1)
        
       # self.bn1 = nn.BatchNorm2d(8)
        
        #self.relu1    = nn.ReLU(inplace=True)
        
        #self.pool1 = nn.MaxPool2d(kernel_size=2)
        
        #second convolution Block
        

       # self.conv2  = nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, stride=1, padding=1)
        
       # self.bn2 = nn.BatchNorm2d(16)
        
       # self.relu2    = nn.ReLU(inplace=True)
        
       # self.pool2 = nn.MaxPool2d(kernel_size=2)
        
        
        
        # out_channels = 8, number of classes = 6
        
        # image width = 120, image height = 120 after two maxpooling 120 -> 60 -> 30
        
        #fully connected layer
        
        #self.fc = nn.Linear(16 * 30 * 30, 6) # adjust the dimesnsions according to the input image size
        
    # Defining the forward pass
   # def forward(self, x):
        
      #  x = self.pool1(self.relu1(self.bn1(self.conv1(x))))
        
       # x = self.pool2(self.relu2(self.bn2(self.conv2(x))))
        
        #x= x.view(x.size(0),-1) # flatten the output
        
        #x= self.fc(x)
        
        #return x
    
    #initialize the model
   # model = EnhancedConvNet()
    #model
        
        
        #out = self.layer_1(x)
        
        #out = self.relu1(out)
        
        #out = self.maxpool1(out)
        
        
        #out = self.layer_2(out)
        
        #out = self.relu2(out)
        
        #out = self.maxpool2(out)
        
        
        #out = out.reshape(out.size(0), -1)
        
        #out = self.drop_out(out)
        
        #out = self.fc1(out)
        
        #return out
    
# Define Model

#model_1 = ConvNet_1()

#print(model_1)



import torch.nn as nn

# CNN Architect
# Enhanced convolutional Neural Network

class EnhancedConvNet(nn.Module):
    
    def __init__(self):
        super(EnhancedConvNet, self).__init__()

        # First convolution Block
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=8, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(8)
        self.relu1 = nn.ReLU(inplace=True)
        self.pool1 = nn.MaxPool2d(kernel_size=2)

        # Second convolution Block
        self.conv2 = nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(16)
        self.relu2 = nn.ReLU(inplace=True)
        self.pool2 = nn.MaxPool2d(kernel_size=2)
        

        # Out_channels = 16, number of classes = 6
        # Image width = 120, image height = 120 after two maxpooling 120 -> 60 -> 30
        # Fully connected layer
        self.fc = nn.Linear(16 * 30 * 30, 6)  # Adjust the dimensions according to the input image size
    
    # Defining the forward pass
    def forward(self, x):
        x = self.pool1(self.relu1(self.bn1(self.conv1(x))))
        x = self.pool2(self.relu2(self.bn2(self.conv2(x))))
        x = x.view(x.size(0), -1)  # Flatten the output
        x = self.fc(x)
        return x

# Initialize the model
model = EnhancedConvNet()

# focal loss implementation

# Import statements

# ...

# Focal Loss implementation
class FocalLoss(nn.Module):
    def __init__(self, alpha=1, gamma=2, logits=False, reduce=True):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.logits = logits
        self.reduce = reduce

    def forward(self, inputs, target):
        if self.logits:
            inputs = torch.sigmoid(inputs)
            BCE_loss = F.binary_cross_entropy(inputs, target, reduction='none')
        else:
            BCE_loss = F.binary_cross_entropy_with_logits(inputs, target, reduction='none')

        pt = torch.exp(-BCE_loss)
        F_loss = self.alpha * (1 - pt) ** self.gamma * BCE_loss

        if self.reduce:
            return torch.mean(F_loss)
        else:
            return F_loss

# Define the model
class EnhancedConvNet(nn.Module):
    def __init__(self):
        super(EnhancedConvNet, self).__init__()

        # First convolution Block
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=8, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(8)
        self.relu1 = nn.ReLU(inplace=True)
        self.pool1 = nn.MaxPool2d(kernel_size=2)

        # Second convolution Block
        self.conv2 = nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(16)
        self.relu2 = nn.ReLU(inplace=True)
        self.pool2 = nn.MaxPool2d(kernel_size=2)

        # Out_channels = 16, number of classes = 6
        # Image width = 120, image height = 120 after two maxpooling 120 -> 60 -> 30
        # Fully connected layer
        self.fc = nn.Linear(16 * 30 * 30, 6)  # Adjust the dimensions according to the input image size

    def forward(self, x):
        x = self.pool1(self.relu1(self.bn1(self.conv1(x))))
        x = self.pool2(self.relu2(self.bn2(self.conv2(x))))
        x = x.view(x.size(0), -1)  # Flatten the output
        x = self.fc(x)
        return x

# Initialize the model
model = EnhancedConvNet()

# Initialize Focal Loss
criterion = FocalLoss()

# Define the optimizer
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Check if GPU is available
if torch.cuda.is_available():
    model = model.cuda()
    criterion = criterion.cuda()
    print(f'Model is started training on {cuda.device_count()} number of gpus.')
    print("Device is cuda")
else:
    print("Device is cpu and model is started training.")

# Training loop
total_step = len(train_data_loader)
loss_list = []
acc_list = []

num_epochs = 1

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

all_con_mat = torch.zeros([num_epochs, 6, 6], dtype=torch.int32, device=device)

for epoch in range(num_epochs):
    con_mat = torch.zeros([6, 6], dtype=torch.int32, device=device)

    for i, data in enumerate(train_data_loader):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        outputs_sigmoid = torch.sigmoid(outputs)
        one_hot_labels = F.one_hot(labels, num_classes=6).float()
        loss = criterion(outputs_sigmoid, one_hot_labels)
        loss.backward()
        optimizer.step()

        loss_list.append(loss.item())
        total = labels.size(0)
        _, predicted = torch.max(outputs.data, 1)
        correct = (predicted == labels).sum().item()
        acc_list.append(correct / total)

        for element in range(total):
            con_mat[predicted[element].item()][labels[element].item()] += 1

        if (i + 1) % 300 == 0:
            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Accuracy: {:.2f}%'
                  .format(epoch + 1, num_epochs, i + 1, total_step, loss.item(),
                          (correct / total) * 100))
    print(con_mat)
    all_con_mat[epoch] = con_mat

print('Finished Training')

# SUM FOR EACH COLUMN

# M N Q S V F

print(torch.sum(con_mat, dim=0))

folder = 'ECG_data/'
list_files(folder)

# RECALL

# PRECISION

# F1-score = 2 × (precision × recall)/(precision + recall)

class_list = ['M','N', 'Q', 'S', 'V', 'F']

f1_score_list=[0,0,0,0,0,0]

precision_list=[0,0,0,0,0,0]

recall_list=[0,0,0,0,0,0]

delta = 0.0000000000001

for i in range(torch.sum(con_mat, dim=0).size(0)): 
    
    recall_list[i] = con_mat[i][i].item()/(torch.sum(con_mat, dim=0)[i].item()+delta)
    
    precision_list[i] = con_mat[i][i].item()/(torch.sum(con_mat, dim=1)[i].item()+delta)
    
    f1_score_list[i] = 2 * precision_list[i]*recall_list[i]/(precision_list[i]+recall_list[i]+delta)
    
    print('class: {:<2},total number of class: {:>6}, Correctly predicted: {:>6}, Recall: {:.2f}%, Precision: {:.2f}%, F1-Score: {:.2f}%'
          
                  .format(class_list[i],
                          torch.sum(con_mat, dim=0)[i].item(),
                          con_mat[i][i].item(), 
                          recall_list[i],
                          precision_list[i],
                          f1_score_list[i]
                         ))
    
    # This part is working

if torch.cuda.is_available():
    
    MODEL = model.cuda()
    CRITERION = criterion.cuda()
    print("cuda")
    
else:
    
    MODEL = model
    CRITERION = criterion
    print("cpu")

# Train the model

total_step = len(train_data_loader)
loss_list = []
acc_list = []

num_epochs = 5

class_list = ['M','N', 'Q', 'S', 'V', 'F']

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

all_con_mat = torch.zeros([num_epochs, 6, 6], dtype=torch.int32, device=device)

for epoch in range(num_epochs):
    f1_score_list=[0,0,0,0,0,0]

    precision_list=[0,0,0,0,0,0]

    recall_list=[0,0,0,0,0,0]
    
    delta = 0.0000000000001 
    
    # define empty tensor 5*5 beginning of every epoch
    # tensor [row,column]
    con_mat = torch.zeros([6, 6], dtype=torch.int32, device=device)
    
    for i, data in enumerate(train_data_loader):
        
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        
        # optimization
        optimizer.zero_grad()
        
        # Forward to get output
        outputs = MODEL(inputs)
        
        outputs_sigmoid = torch.sigmoid(outputs)
        
        one_hot_labels = F.one_hot(labels, num_classes=6).float()
        # Calculate Loss
        loss = CRITERION(outputs_sigmoid, one_hot_labels)
        # Backward propagation
        loss.backward()
        # Updating parameters
        optimizer.step()
        
        # Store loss
        loss_list.append(loss.item())
    
        # Calculate labels size
        total = labels.size(0)
        
        # Outputs.data has dimension batch size * 5
        # torch.max returns the max value of elements(_) and their indices(predicted) in the tensor array
        _, predicted = torch.max(outputs.data, 1)
        
        # Calculate total number of correct labels 
        correct = (predicted == labels).sum().item()
        
        # Store accuracy
        acc_list.append(correct / total)
        
        for element in range(total):
            
            # con_mat[row,column]
            # con_mat[predictions, actual]
            con_mat[predicted[element].item()-1][labels[element].item()-1] += 1

        if (i + 1) % 300 == 0:                             # every 300 mini-batches...
            
            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Accuracy: {:.2f}%'
                  
                  .format(epoch + 1, num_epochs, i + 1, total_step, loss.item(),
                          (correct / total) * 100))
    print(con_mat)
            
    all_con_mat[epoch] = con_mat
    
    # Print Confusion Matrix
    
    for i in range(torch.sum(con_mat, dim=0).size(0)): 
    
        recall_list[i] = con_mat[i][i].item()/(torch.sum(con_mat, dim=0)[i].item()+delta)
    
        precision_list[i] = con_mat[i][i].item()/(torch.sum(con_mat, dim=1)[i].item()+delta)
    
        f1_score_list[i] = 2 * precision_list[i]*recall_list[i]/(precision_list[i]+recall_list[i]+delta)
        
    
        print('class name: {}, total number of class: {:>6}, Correctly predicted: {:>6}, Recall: {:.2f}%, Precision: {:.2f}%, F1-Score: {:.2f}%'
          
                  .format(class_list[i],
                          torch.sum(con_mat, dim=0)[i].item(),
                          con_mat[i][i].item(), 
                          recall_list[i],
                          precision_list[i],
                          f1_score_list[i]
                         ))
        
print('Finished Training')

plt.plot(loss_list);
plt.show();

plt.plot(acc_list);
plt.show();

all_con_mat

#Check Trained 1. Model on the Test Data
confusion_mat = torch.zeros([6, 6], dtype=torch.int32, device=device)

with torch.no_grad():
    
    for data in test_data_loader:
        
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        
        outputs = MODEL(inputs)
        
        _, predicted = torch.max(outputs.data, 1)
        
        total = labels.size(0)
        
        # Calculate total number of correct labels 
        correct = (predicted == labels).sum().item()
        
        for element in range(total):
            
            # confusion_mat[row,column]
            # confusion_mat[predictions, actual]
            confusion_mat[predicted[element].item()-1][labels[element].item()-1] += 1

    print(confusion_mat)
    

class_list = ['M','N', 'Q', 'S', 'V', 'F']

f1_score_list=[0,0,0,0,0,0]

precision_list=[0,0,0,0,0,0]

recall_list=[0,0,0,0,0,0]
    
delta = 0.0000000000001 


for i in range(torch.sum(confusion_mat, dim=0).size(0)): 
    
        recall_list[i] = confusion_mat[i][i].item()/(torch.sum(confusion_mat, dim=0)[i].item()+delta)
    
        precision_list[i] = confusion_mat[i][i].item()/(torch.sum(confusion_mat, dim=1)[i].item()+delta)
    
        f1_score_list[i] = 2 * precision_list[i]*recall_list[i]/(precision_list[i]+recall_list[i]+delta)
        
        print('class name: {}, total number of class: {:>6}, Correctly predicted: {:>6}, Recall: {:.2f}%, Precision: {:.2f}%, F1-Score: {:.2f}%'
          
                  .format(class_list[i],
                          torch.sum(confusion_mat, dim=0)[i].item(),
                          confusion_mat[i][i].item(), 
                          recall_list[i],
                          precision_list[i],
                          f1_score_list[i]
                         ))
# Out:
# ['test', 'train']
# ['test', 'train']
#  - 2
# test - 6
#     F - 161
#     M - 2101
#     N - 18926
#     Q - 1608
#     S - 556
#     V - 1447
# train - 6
#     F - 642
#     M - 8405
#     N - 75709
#     Q - 6431
#     S - 2223
#     V - 5789
#  - 2
# test - 6
#     F - 161
#     M - 2101
#     N - 18926
#     Q - 1608
#     S - 556
#     V - 1447
# train - 6
#     F - 642
#     M - 8405
#     N - 75709
#     Q - 6431
#     S - 2223
#     V - 5789
# ['F', 'M', 'N', 'Q', 'S', 'V']
# There are 6 different classes.
# ['F', 'M', 'N', 'Q', 'S', 'V']
# # of Normal beats:  18926
# # of Fusion beats:  161
# # of Unknown beats:  1608
# # of Ventricular ectopic beats:  1447
# # of Supraventricular ectopic beats:  556
# # of M-Research ectopic beats:  2101
# N10007.png
# (288, 432, 4)
# <class 'numpy.ndarray'>
# ECG_data/test/N/N10007.png
# ECG_data/test/N/N10010.png
# ECG_data/test/N/N10014.png
# ECG_data/test/N/N10019.png
# ECG_data/test/N/N10025.png
# ECG_data/test/N/N10034.png
# ECG_data/test/S/S100.png
# ECG_data/test/S/S1008.png
# ECG_data/test/S/S1010.png
# ECG_data/test/S/S1018.png
# ECG_data/test/S/S1021.png
# ECG_data/test/S/S1030.png
# ECG_data/test/Q/Q1.png
# ECG_data/test/Q/Q1002.png
# ECG_data/test/Q/Q1003.png
# ECG_data/test/Q/Q1009.png
# ECG_data/test/Q/Q1011.png
# ECG_data/test/Q/Q1021.png
# ECG_data/test/M/M0.png
# ECG_data/test/M/M1.png
# ECG_data/test/M/M10.png
# ECG_data/test/M/M100.png
# ECG_data/test/M/M1000.png
# ECG_data/test/M/M1001.png
# ECG_data/test/V/V1001.png
# ECG_data/test/V/V1006.png
# ECG_data/test/V/V1012.png
# ECG_data/test/V/V102.png
# ECG_data/test/V/V1023.png
# ECG_data/test/V/V1030.png
# ECG_data/test/F/F0.png
# ECG_data/test/F/F104.png
# ECG_data/test/F/F113.png
# ECG_data/test/F/F115.png
# ECG_data/test/F/F118.png
# ECG_data/test/F/F12.png
# OpenCV version: 4.8.0
# NumPy version: 1.21.5
# (288, 432, 3)
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
# ECG_data/
# ECG_data/test
# ECG_data/test\F
# ECG_data/test\M
# ECG_data/test\N
# ECG_data/test\Q
# ECG_data/test\S
# ECG_data/test\V
# ECG_data/train
# ECG_data/train\F
# ECG_data/train\M
# ECG_data/train\N
# ECG_data/train\Q
# ECG_data/train\S
# ECG_data/train\V
#  - 2
# test - 6
#     F - 161
#     M - 2101
#     N - 18926
#     Q - 1608
#     S - 556
#     V - 1447
# train - 6
#     F - 642
#     M - 8405
#     N - 75709
#     Q - 6431
#     S - 2223
#     V - 5789
# number of N images at the original file:  75709
# total number of train and test picts:     94635
# number of S images at the original file:  2223
# total number of train and test picts:     2779
# number of F images at the original file:  642
# total number of train and test picts:     803
# number of V images at the original file:  5789
# total number of train and test picts:     7236
# number of M images at the original file:  8405
# total number of train and test picts:     10506
# number of Q images at the original file:  6431
# total number of train and test picts:     8039
# <class 'torch.Tensor'>
# torch.Size([32, 1, 120, 120])
#
# Batch Size:    32
# Channel Size:  1
# Image Height:  120
# Image Width:   120
# <AxesSubplot:>
#     M     F     S     F     F     F     S     F
#     F     M     F     F     F     M     F     F
#     F     F     F     F     F     F     F     F
#     M     M     F     F     F     F     F     F
# Device is cpu and model is started training.
# Epoch [1/1], Step [300/3100], Loss: 0.1600, Accuracy: 78.12%
# Epoch [1/1], Step [600/3100], Loss: 0.1600, Accuracy: 78.12%
# Epoch [1/1], Step [900/3100], Loss: 0.1605, Accuracy: 71.88%
# Epoch [1/1], Step [1200/3100], Loss: 0.1579, Accuracy: 81.25%
# Epoch [1/1], Step [1500/3100], Loss: 0.1611, Accuracy: 68.75%
# Epoch [1/1], Step [1800/3100], Loss: 0.1571, Accuracy: 71.88%
# Epoch [1/1], Step [2100/3100], Loss: 0.1626, Accuracy: 65.62%
# Epoch [1/1], Step [2400/3100], Loss: 0.1602, Accuracy: 65.62%
# Epoch [1/1], Step [2700/3100], Loss: 0.1583, Accuracy: 75.00%
# Epoch [1/1], Step [3000/3100], Loss: 0.1600, Accuracy: 65.62%
# tensor([[    0,    11,    18,     2,     0,     5],
#         [    2,    72,    62,     4,     2,    34],
#         [  640,  8166, 75622,  6425,  2219,  5601],
#         [    0,    36,     5,     0,     1,   122],
#         [    0,    80,     1,     0,     1,    27],
#         [    0,    40,     1,     0,     0,     0]], dtype=torch.int32)
# Finished Training
# tensor([  642,  8405, 75709,  6431,  2223,  5789])
#  - 2
# test - 6
#     F - 161
#     M - 2101
#     N - 18926
#     Q - 1608
#     S - 556
#     V - 1447
# train - 6
#     F - 642
#     M - 8405
#     N - 75709
#     Q - 6431
#     S - 2223
#     V - 5789
# class: M ,total number of class:    642, Correctly predicted:      0, Recall: 0.00%, Precision: 0.00%, F1-Score: 0.00%
# class: N ,total number of class:   8405, Correctly predicted:     72, Recall: 0.01%, Precision: 0.41%, F1-Score: 0.02%
# class: Q ,total number of class:  75709, Correctly predicted:  75622, Recall: 1.00%, Precision: 0.77%, F1-Score: 0.87%
# class: S ,total number of class:   6431, Correctly predicted:      0, Recall: 0.00%, Precision: 0.00%, F1-Score: 0.00%
# class: V ,total number of class:   2223, Correctly predicted:      1, Recall: 0.00%, Precision: 0.01%, F1-Score: 0.00%
# class: F ,total number of class:   5789, Correctly predicted:      0, Recall: 0.00%, Precision: 0.00%, F1-Score: 0.00%
# cpu
# Epoch [1/5], Step [300/3100], Loss: 0.1526, Accuracy: 87.50%
# Epoch [1/5], Step [600/3100], Loss: 0.1569, Accuracy: 71.88%
# Epoch [1/5], Step [900/3100], Loss: 0.1639, Accuracy: 56.25%
# Epoch [1/5], Step [1200/3100], Loss: 0.1552, Accuracy: 81.25%
# Epoch [1/5], Step [1500/3100], Loss: 0.1602, Accuracy: 65.62%
# Epoch [1/5], Step [1800/3100], Loss: 0.1573, Accuracy: 75.00%
# Epoch [1/5], Step [2100/3100], Loss: 0.1558, Accuracy: 78.12%
# Epoch [1/5], Step [2400/3100], Loss: 0.1606, Accuracy: 68.75%
# Epoch [1/5], Step [2700/3100], Loss: 0.1607, Accuracy: 71.88%
# Epoch [1/5], Step [3000/3100], Loss: 0.1549, Accuracy: 81.25%
# tensor([[  168,     0,     0,     3,   225,     7],
#         [ 7849, 75709,  6431,  2213,  4958,   633],
#         [   98,     0,     0,     4,   489,     2],
#         [  174,     0,     0,     3,    97,     0],
#         [   82,     0,     0,     0,     2,     0],
#         [   34,     0,     0,     0,    18,     0]], dtype=torch.int32)
# class name: M, total number of class:   8405, Correctly predicted:    168, Recall: 0.02%, Precision: 0.42%, F1-Score: 0.04%
# class name: N, total number of class:  75709, Correctly predicted:  75709, Recall: 1.00%, Precision: 0.77%, F1-Score: 0.87%
# class name: Q, total number of class:   6431, Correctly predicted:      0, Recall: 0.00%, Precision: 0.00%, F1-Score: 0.00%
# class name: S, total number of class:   2223, Correctly predicted:      3, Recall: 0.00%, Precision: 0.01%, F1-Score: 0.00%
# class name: V, total number of class:   5789, Correctly predicted:      2, Recall: 0.00%, Precision: 0.02%, F1-Score: 0.00%
# class name: F, total number of class:    642, Correctly predicted:      0, Recall: 0.00%, Precision: 0.00%, F1-Score: 0.00%
# Epoch [2/5], Step [300/3100], Loss: 0.1596, Accuracy: 62.50%
# Epoch [2/5], Step [600/3100], Loss: 0.1573, Accuracy: 75.00%
# Epoch [2/5], Step [900/3100], Loss: 0.1539, Accuracy: 81.25%
# Epoch [2/5], Step [1200/3100], Loss: 0.1594, Accuracy: 71.88%
# Epoch [2/5], Step [1500/3100], Loss: 0.1571, Accuracy: 71.88%
# Epoch [2/5], Step [1800/3100], Loss: 0.1565, Accuracy: 71.88%
# Epoch [2/5], Step [2100/3100], Loss: 0.1595, Accuracy: 62.50%
# Epoch [2/5], Step [2400/3100], Loss: 0.1588, Accuracy: 71.88%
# Epoch [2/5], Step [2700/3100], Loss: 0.1583, Accuracy: 65.62%
# Epoch [2/5], Step [3000/3100], Loss: 0.1578, Accuracy: 75.00%
# tensor([[  215,     0,     0,     5,   418,    10],
#         [ 7735, 75709,  6431,  2206,  4392,   628],
#         [  134,     0,     0,     9,   791,     3],
#         [  192,     0,     0,     3,   152,     1],
#         [   92,     0,     0,     0,    14,     0],
#         [   37,     0,     0,     0,    22,     0]], dtype=torch.int32)
# class name: M, total number of class:   8405, Correctly predicted:    215, Recall: 0.03%, Precision: 0.33%, F1-Score: 0.05%
# class name: N, total number of class:  75709, Correctly predicted:  75709, Recall: 1.00%, Precision: 0.78%, F1-Score: 0.88%
# class name: Q, total number of class:   6431, Correctly predicted:      0, Recall: 0.00%, Precision: 0.00%, F1-Score: 0.00%
# class name: S, total number of class:   2223, Correctly predicted:      3, Recall: 0.00%, Precision: 0.01%, F1-Score: 0.00%
# class name: V, total number of class:   5789, Correctly predicted:     14, Recall: 0.00%, Precision: 0.13%, F1-Score: 0.00%
# class name: F, total number of class:    642, Correctly predicted:      0, Recall: 0.00%, Precision: 0.00%, F1-Score: 0.00%
# Epoch [3/5], Step [300/3100], Loss: 0.1581, Accuracy: 68.75%
# Epoch [3/5], Step [600/3100], Loss: 0.1559, Accuracy: 81.25%
# Epoch [3/5], Step [900/3100], Loss: 0.1545, Accuracy: 84.38%
# Epoch [3/5], Step [1200/3100], Loss: 0.1541, Accuracy: 81.25%
# Epoch [3/5], Step [1500/3100], Loss: 0.1534, Accuracy: 81.25%
# Epoch [3/5], Step [1800/3100], Loss: 0.1549, Accuracy: 75.00%
# Epoch [3/5], Step [2100/3100], Loss: 0.1595, Accuracy: 65.62%
# Epoch [3/5], Step [2400/3100], Loss: 0.1528, Accuracy: 84.38%
# Epoch [3/5], Step [2700/3100], Loss: 0.1573, Accuracy: 71.88%
# Epoch [3/5], Step [3000/3100], Loss: 0.1560, Accuracy: 71.88%
# tensor([[  240,     0,     0,     6,   499,    11],
#         [ 7669, 75709,  6431,  2203,  3997,   627],
#         [  171,     0,     0,    10,  1072,     3],
#         [  199,     0,     0,     4,   169,     1],
#         [   92,     0,     0,     0,    23,     0],
#         [   34,     0,     0,     0,    29,     0]], dtype=torch.int32)
# class name: M, total number of class:   8405, Correctly predicted:    240, Recall: 0.03%, Precision: 0.32%, F1-Score: 0.05%
# class name: N, total number of class:  75709, Correctly predicted:  75709, Recall: 1.00%, Precision: 0.78%, F1-Score: 0.88%
# class name: Q, total number of class:   6431, Correctly predicted:      0, Recall: 0.00%, Precision: 0.00%, F1-Score: 0.00%
# class name: S, total number of class:   2223, Correctly predicted:      4, Recall: 0.00%, Precision: 0.01%, F1-Score: 0.00%
# class name: V, total number of class:   5789, Correctly predicted:     23, Recall: 0.00%, Precision: 0.20%, F1-Score: 0.01%
# class name: F, total number of class:    642, Correctly predicted:      0, Recall: 0.00%, Precision: 0.00%, F1-Score: 0.00%
# Epoch [4/5], Step [300/3100], Loss: 0.1543, Accuracy: 78.12%
# Epoch [4/5], Step [600/3100], Loss: 0.1574, Accuracy: 78.12%
# Epoch [4/5], Step [900/3100], Loss: 0.1522, Accuracy: 90.62%
# Epoch [4/5], Step [1200/3100], Loss: 0.1630, Accuracy: 62.50%
# Epoch [4/5], Step [1500/3100], Loss: 0.1534, Accuracy: 81.25%
# Epoch [4/5], Step [1800/3100], Loss: 0.1526, Accuracy: 84.38%
# Epoch [4/5], Step [2100/3100], Loss: 0.1556, Accuracy: 75.00%
# Epoch [4/5], Step [2400/3100], Loss: 0.1559, Accuracy: 78.12%
# Epoch [4/5], Step [2700/3100], Loss: 0.1555, Accuracy: 75.00%
# Epoch [4/5], Step [3000/3100], Loss: 0.1618, Accuracy: 62.50%
# tensor([[  245,     0,     0,     6,   534,    13],
#         [ 7631, 75708,  6431,  2201,  3773,   625],
#         [  197,     1,     0,    12,  1217,     3],
#         [  205,     0,     0,     4,   198,     1],
#         [   92,     0,     0,     0,    24,     0],
#         [   35,     0,     0,     0,    43,     0]], dtype=torch.int32)
# class name: M, total number of class:   8405, Correctly predicted:    245, Recall: 0.03%, Precision: 0.31%, F1-Score: 0.05%
# class name: N, total number of class:  75709, Correctly predicted:  75708, Recall: 1.00%, Precision: 0.79%, F1-Score: 0.88%
# class name: Q, total number of class:   6431, Correctly predicted:      0, Recall: 0.00%, Precision: 0.00%, F1-Score: 0.00%
# class name: S, total number of class:   2223, Correctly predicted:      4, Recall: 0.00%, Precision: 0.01%, F1-Score: 0.00%
# class name: V, total number of class:   5789, Correctly predicted:     24, Recall: 0.00%, Precision: 0.21%, F1-Score: 0.01%
# class name: F, total number of class:    642, Correctly predicted:      0, Recall: 0.00%, Precision: 0.00%, F1-Score: 0.00%
# Epoch [5/5], Step [300/3100], Loss: 0.1571, Accuracy: 68.75%
# Epoch [5/5], Step [600/3100], Loss: 0.1534, Accuracy: 81.25%
# Epoch [5/5], Step [900/3100], Loss: 0.1544, Accuracy: 81.25%
# Epoch [5/5], Step [1200/3100], Loss: 0.1593, Accuracy: 68.75%
# Epoch [5/5], Step [1500/3100], Loss: 0.1525, Accuracy: 84.38%
# Epoch [5/5], Step [1800/3100], Loss: 0.1602, Accuracy: 68.75%
# Epoch [5/5], Step [2100/3100], Loss: 0.1557, Accuracy: 71.88%
# Epoch [5/5], Step [2400/3100], Loss: 0.1589, Accuracy: 62.50%
# Epoch [5/5], Step [2700/3100], Loss: 0.1526, Accuracy: 84.38%
# Epoch [5/5], Step [3000/3100], Loss: 0.1548, Accuracy: 75.00%
# tensor([[  262,     0,     0,     7,   551,    13],
#         [ 7580, 75708,  6431,  2200,  3645,   624],
#         [  220,     1,     0,    12,  1291,     3],
#         [  218,     0,     0,     4,   225,     1],
#         [   89,     0,     0,     0,    24,     1],
#         [   36,     0,     0,     0,    53,     0]], dtype=torch.int32)
# class name: M, total number of class:   8405, Correctly predicted:    262, Recall: 0.03%, Precision: 0.31%, F1-Score: 0.06%
# class name: N, total number of class:  75709, Correctly predicted:  75708, Recall: 1.00%, Precision: 0.79%, F1-Score: 0.88%
# class name: Q, total number of class:   6431, Correctly predicted:      0, Recall: 0.00%, Precision: 0.00%, F1-Score: 0.00%
# class name: S, total number of class:   2223, Correctly predicted:      4, Recall: 0.00%, Precision: 0.01%, F1-Score: 0.00%
# class name: V, total number of class:   5789, Correctly predicted:     24, Recall: 0.00%, Precision: 0.21%, F1-Score: 0.01%
# class name: F, total number of class:    642, Correctly predicted:      0, Recall: 0.00%, Precision: 0.00%, F1-Score: 0.00%
# Finished Training
# tensor([[[  168,     0,     0,     3,   225,     7],
#          [ 7849, 75709,  6431,  2213,  4958,   633],
#          [   98,     0,     0,     4,   489,     2],
#          [  174,     0,     0,     3,    97,     0],
#          [   82,     0,     0,     0,     2,     0],
#          [   34,     0,     0,     0,    18,     0]],
#
#         [[  215,     0,     0,     5,   418,    10],
#          [ 7735, 75709,  6431,  2206,  4392,   628],
#          [  134,     0,     0,     9,   791,     3],
#          [  192,     0,     0,     3,   152,     1],
#          [   92,     0,     0,     0,    14,     0],
#          [   37,     0,     0,     0,    22,     0]],
#
#         [[  240,     0,     0,     6,   499,    11],
#          [ 7669, 75709,  6431,  2203,  3997,   627],
#          [  171,     0,     0,    10,  1072,     3],
#          [  199,     0,     0,     4,   169,     1],
#          [   92,     0,     0,     0,    23,     0],
#          [   34,     0,     0,     0,    29,     0]],
#
#         [[  245,     0,     0,     6,   534,    13],
#          [ 7631, 75708,  6431,  2201,  3773,   625],
#          [  197,     1,     0,    12,  1217,     3],
#          [  205,     0,     0,     4,   198,     1],
#          [   92,     0,     0,     0,    24,     0],
#          [   35,     0,     0,     0,    43,     0]],
#
#         [[  262,     0,     0,     7,   551,    13],
#          [ 7580, 75708,  6431,  2200,  3645,   624],
#          [  220,     1,     0,    12,  1291,     3],
#          [  218,     0,     0,     4,   225,     1],
#          [   89,     0,     0,     0,    24,     1],
#          [   36,     0,     0,     0,    53,     0]]], dtype=torch.int32)
# tensor([[   72,     0,     0,     0,   185,     7],
#         [ 1875, 18926,  1608,   553,   873,   154],
#         [   76,     0,     0,     3,   307,     0],
#         [   46,     0,     0,     0,    46,     0],
#         [   24,     0,     0,     0,    11,     0],
#         [    8,     0,     0,     0,    25,     0]], dtype=torch.int32)
# class name: M, total number of class:   2101, Correctly predicted:     72, Recall: 0.03%, Precision: 0.27%, F1-Score: 0.06%
# class name: N, total number of class:  18926, Correctly predicted:  18926, Recall: 1.00%, Precision: 0.79%, F1-Score: 0.88%
# class name: Q, total number of class:   1608, Correctly predicted:      0, Recall: 0.00%, Precision: 0.00%, F1-Score: 0.00%
# class name: S, total number of class:    556, Correctly predicted:      0, Recall: 0.00%, Precision: 0.00%, F1-Score: 0.00%
# class name: V, total number of class:   1447, Correctly predicted:     11, Recall: 0.01%, Precision: 0.31%, F1-Score: 0.01%
# class name: F, total number of class:    161, Correctly predicted:      0, Recall: 0.00%, Precision: 0.00%, F1-Score: 0.00%
