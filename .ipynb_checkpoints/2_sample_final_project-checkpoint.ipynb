# %% [markdown]
# Import Packages

# %%
# for numerical analysis
import numpy as np # linear algebra

# to store and process in a dataframe
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Visualizations, for ploting graphs
import matplotlib.pyplot as plt

# image processing
import matplotlib.image as mpimg

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# advanced ploting
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# Image manipulations
from PIL import Image
#from libjpeg import decode

# Timing utility
from timeit import default_timer as timer

from IPython.core.interactiveshell import InteractiveShell

# Printing out all outputs
InteractiveShell.ast_node_interactivity = 'all'

# %%
# PyTorch
import torchvision
from torchvision import transforms, datasets, models

import torch
from torch import optim, cuda
from torch.utils.data import DataLoader, sampler
from torch.autograd import Variable

import torch.nn as nn
import torch.nn.functional as F

from torch.nn import Linear, ReLU, CrossEntropyLoss, Sequential, Conv2d, MaxPool2d
from torch.nn import Module, Softmax, BatchNorm2d, Dropout

import gc
# Out:
# C:\Users\Brian Ashiali\anaconda3\lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: '[WinError 127] The specified procedure could not be found'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
# file operations

import shutil
import os
from os import walk

# to list files
import glob

print(os.listdir("ecg_img/"))
# Out:
# ['test', 'train']

# %%
# current working directory
os.getcwd()
# Out:
# 'C:\\Users\\Brian Ashiali\\Desktop\\Ml_class\\class_1\\FiN_project_Ml\\sample_final_pract'

# %%
# no. of files

def list_files(startpath):
    
    for root, dirs, files in os.walk(startpath):
        
        level = root.replace(startpath, '').count(os.sep)
        
        indent = ' ' * 4 * (level)
        
        print('{}{}'.format(indent, os.path.basename(root)), '-', len(os.listdir(root)))
        
folder = 'ecg_img/'
list_files(folder)
# Out:
#  - 2
# test - 5
#     F - 1
#         F - 161
#     N - 5
#         e - 4
#         j - 46
#         L - 1614
#         N - 10545
#         R - 1452
#     Q - 3
#         f - 197
#         p - 1404
#         Q - 7
#     S - 4
#         A - 530
#         aa - 9
#         J - 17
#         S - 1
#     V - 2
#         E - 22
#         V - 1426
# train - 5
#     F - 1
#         F - 641
#     N - 5
#         e - 12
#         j - 183
#         L - 6454
#         N - 9676
#         R - 5797
#     Q - 3
#         f - 785
#         p - 5602
#         Q - 26
#     S - 4
#         A - 2035
#         aa - 120
#         J - 66
#         S - 1
#     V - 2
#         E - 84
#         V - 5696

# %%
folder = 'ecg_img/'
list_files(folder)
# Out:
#  - 2
# test - 5
#     F - 1
#         F - 161
#     N - 5
#         e - 4
#         j - 46
#         L - 1614
#         N - 10545
#         R - 1452
#     Q - 3
#         f - 197
#         p - 1404
#         Q - 7
#     S - 4
#         A - 530
#         aa - 9
#         J - 17
#         S - 1
#     V - 2
#         E - 22
#         V - 1426
# train - 5
#     F - 1
#         F - 641
#     N - 5
#         e - 12
#         j - 183
#         L - 6454
#         N - 9676
#         R - 5797
#     Q - 3
#         f - 785
#         p - 5602
#         Q - 26
#     S - 4
#         A - 2035
#         aa - 120
#         J - 66
#         S - 1
#     V - 2
#         E - 84
#         V - 5696

# %%
# list of files in the dataset /input/ecg-images/MITBIH_img

os.listdir('ecg_img/test/')
# Out:
# ['F', 'N', 'Q', 'S', 'V']

# %%
# Classes in the data

ECG_list = os.listdir('ecg_img/test/')

n_classes = len(ECG_list)

print(f'There are {n_classes} different classes.')
# Out:
# There are 5 different classes.

# %%
ECG_list
# Out:
# ['F', 'N', 'Q', 'S', 'V']

# %%
classes = ('S', 'V', 'Q', 'N', 'F')

# %% [markdown]
# Count Number of Files in the MITBIH_img Folder

# %%
N_imgs = os.listdir('ecg_img/test/N/N/')
print('# of Normal beats: ',len(N_imgs))

F_imgs = os.listdir('ecg_img/test/F/F/')
print('# of Fusion beats: ',len(F_imgs))

Q_imgs = os.listdir('ecg_img/test/Q/Q/')
print('# of Unknown beats: ',len(Q_imgs))

V_imgs = os.listdir('ecg_img/test/V/V/')
print('# of Ventricular ectopic beats: ',len(V_imgs))

S_imgs = os.listdir('ecg_img/test/S/S/')
print('# of Supraventricular ectopic beats: ',len(S_imgs))
# Out:
# # of Normal beats:  10545
# # of Fusion beats:  161
# # of Unknown beats:  7
# # of Ventricular ectopic beats:  1426
# # of Supraventricular ectopic beats:  1

# %%
#print(N_dir)
print(N_imgs[0])
# Out:
# Nfig_19460.png

# %% [markdown]
# EDA

# %%
def imshow(image):
    """Display image"""
    plt.figure(figsize=(6, 6))
    plt.imshow(image)
    plt.axis('off')
    plt.show()

# %%
image = mpimg.imread(os.path.join('ecg_img/test/N/N/', N_imgs[0]))

imshow(image)

# %%
print(image.shape)
print(type(image))
# Out:
# (256, 256)
# <class 'numpy.ndarray'>

# %% [markdown]
# Show Images From Each Folder

# %%
# Define a function which will plot several images

def image_shows(folder, number_of_images):
    
    n=number_of_images;
    
    folder_list = os.listdir(folder)
    
    fig, axes = plt.subplots(nrows = 1, ncols=n, figsize=(20, 10))
    
    for i in range(n):
        
        print(os.path.join(folder, folder_list[i]))
        
        image = mpimg.imread(os.path.join(folder, folder_list[i]));
        
        axes[i].imshow(image);

# %%
# Examples of N

image_shows(folder = 'ecg_img/test/N/N/', number_of_images = 6)
# Out:
# ecg_img/test/N/N/Nfig_19460.png
# ecg_img/test/N/N/Nfig_19567.png
# ecg_img/test/N/N/Nfig_19614.png
# ecg_img/test/N/N/Nfig_19645.png
# ecg_img/test/N/N/Nfig_19696.png
# ecg_img/test/N/N/Nfig_19700.png

# %%
# Examples of S

image_shows(folder = 'ecg_img/test/S/J/', number_of_images = 6)
# Out:
# ecg_img/test/S/J/fig_31200008.png
# ecg_img/test/S/J/fig_31200013.png
# ecg_img/test/S/J/fig_31200021.png
# ecg_img/test/S/J/fig_31200026.png
# ecg_img/test/S/J/fig_31200039.png
# ecg_img/test/S/J/fig_31200042.png

# %%
# Examples of Q

image_shows(folder = 'ecg_img/test/Q/Q/', number_of_images = 6)
# Out:
# ecg_img/test/Q/Q/Qfig_19.png
# ecg_img/test/Q/Q/Qfig_20.png
# ecg_img/test/Q/Q/Qfig_28.png
# ecg_img/test/Q/Q/Qfig_30.png
# ecg_img/test/Q/Q/Qfig_31.png
# ecg_img/test/Q/Q/Qfig_33.png

# %%
# Examples of V

image_shows(folder = 'ecg_img/test/V/V/', number_of_images = 6)
# Out:
# ecg_img/test/V/V/Vfig_1.png
# ecg_img/test/V/V/Vfig_10.png
# ecg_img/test/V/V/Vfig_1009.png
# ecg_img/test/V/V/Vfig_101.png
# ecg_img/test/V/V/Vfig_1013.png
# ecg_img/test/V/V/Vfig_1014.png

# %%
# Examples of F

image_shows(folder = 'ecg_img/test/F/F/', number_of_images = 6)
# Out:
# ecg_img/test/F/F/Ffig_11.png
# ecg_img/test/F/F/Ffig_114.png
# ecg_img/test/F/F/Ffig_115.png
# ecg_img/test/F/F/Ffig_121.png
# ecg_img/test/F/F/Ffig_126.png
# ecg_img/test/F/F/Ffig_135.png

# %% [markdown]
# To see 3 channels I plot figures with cv 2 package

# %%
#import cv2
import cv2
import numpy as np

print("OpenCV version:", cv2.__version__)
print("NumPy version:", np.__version__)
# Out:
# OpenCV version: 4.8.1
# NumPy version: 1.21.5

# %%
import cv2

# %%
imgcv = cv2.imread(os.path.join('ecg_img/test/N/N/', N_imgs[0]))
plt.imshow(imgcv)
plt.show();

# %%
imgcv.shape
# Out:
# (256, 256, 3)

# %%
b = imgcv.copy()
# set green and red channels to 0
b[:, :, 1] = 0
b[:, :, 2] = 0


g = imgcv.copy()
# set blue and red channels to 0
g[:, :, 0] = 0
g[:, :, 2] = 0

r = imgcv.copy()
# set blue and green channels to 0
r[:, :, 0] = 0
r[:, :, 1] = 0

# %% [markdown]
# plot rgb

# %%
# plot data

fig = plt.figure(figsize=(15,15))

plot_1 = plt.subplot(131)
plot_1.imshow(r);

#plt.subplot(131).imshow(b);

plot_2 = plt.subplot(132, sharex=plot_1, sharey=plot_1)
plt.setp(plot_2.get_yticklabels(), visible=False);
plot_2.imshow(b);

plot_3 = plt.subplot(133, sharex=plot_1, sharey=plot_1)
plt.setp(plot_3.get_yticklabels(), visible=False);
plot_3.imshow(g);

plt.show();

# %%
for root, dirs, files in os.walk('ecg_img/'):
    print(root)
    #So, as the code runs, it will print the paths of all directories
    #within the '/ecg/' directory and its subdirectories.
# Out:
# ecg_img/
# ecg_img/test
# ecg_img/test\F
# ecg_img/test\F\F
# ecg_img/test\N
# ecg_img/test\N\e
# ecg_img/test\N\j
# ecg_img/test\N\L
# ecg_img/test\N\N
# ecg_img/test\N\R
# ecg_img/test\Q
# ecg_img/test\Q\f
# ecg_img/test\Q\p
# ecg_img/test\Q\Q
# ecg_img/test\S
# ecg_img/test\S\A
# ecg_img/test\S\aa
# ecg_img/test\S\J
# ecg_img/test\S\S
# ecg_img/test\V
# ecg_img/test\V\E
# ecg_img/test\V\V
# ecg_img/train
# ecg_img/train\F
# ecg_img/train\F\F
# ecg_img/train\N
# ecg_img/train\N\e
# ecg_img/train\N\j
# ecg_img/train\N\L
# ecg_img/train\N\N
# ecg_img/train\N\R
# ecg_img/train\Q
# ecg_img/train\Q\f
# ecg_img/train\Q\p
# ecg_img/train\Q\Q
# ecg_img/train\S
# ecg_img/train\S\A
# ecg_img/train\S\aa
# ecg_img/train\S\J
# ecg_img/train\S\S
# ecg_img/train\V
# ecg_img/train\V\E
# ecg_img/train\V\V

# %%
folder = 'ecg_img/'
list_files(folder)
# Out:
#  - 2
# test - 5
#     F - 1
#         F - 161
#     N - 5
#         e - 4
#         j - 46
#         L - 1614
#         N - 10545
#         R - 1452
#     Q - 3
#         f - 197
#         p - 1404
#         Q - 7
#     S - 4
#         A - 530
#         aa - 9
#         J - 17
#         S - 1
#     V - 2
#         E - 22
#         V - 1426
# train - 5
#     F - 1
#         F - 641
#     N - 5
#         e - 12
#         j - 183
#         L - 6454
#         N - 9676
#         R - 5797
#     Q - 3
#         f - 785
#         p - 5602
#         Q - 26
#     S - 4
#         A - 2035
#         aa - 120
#         J - 66
#         S - 1
#     V - 2
#         E - 84
#         V - 5696

# %%
N_imgs       = len(os.listdir('ecg_img/train/N/N/'))
N_train_imgs = len(os.listdir('ecg_img/train/N/N/'))
N_test_imgs  = len(os.listdir('ecg_img/test/N/N/'))
print('number of N images at the original file: ', N_imgs)
print('total number of train and test picts:    ', N_train_imgs + N_test_imgs)
# Out:
# number of N images at the original file:  9676
# total number of train and test picts:     20221

# %%
S_imgs       = len(os.listdir('ecg_img/train/S/A/'))
S_train_imgs = len(os.listdir('ecg_img/train/S/A/'))
S_test_imgs  = len(os.listdir('ecg_img/test/S/A/'))
print('number of S images at the original file: ', S_imgs)
print('total number of train and test picts:    ', S_train_imgs + S_test_imgs)
# Out:
# number of S images at the original file:  2035
# total number of train and test picts:     2565

# %%
F_imgs       = len(os.listdir('ecg_img/train/F/F/'))
F_train_imgs = len(os.listdir('ecg_img/train/F/F/'))
F_test_imgs  = len(os.listdir('ecg_img/test/F/F/'))
print('number of F images at the original file: ', F_imgs)
print('total number of train and test picts:    ', F_train_imgs + F_test_imgs)
# Out:
# number of F images at the original file:  641
# total number of train and test picts:     802

# %%
V_imgs       = len(os.listdir('ecg_img/train/V/V/'))
V_train_imgs = len(os.listdir('ecg_img/train/V/V/'))
V_test_imgs  = len(os.listdir('ecg_img/test/V/V/'))
print('number of V images at the original file: ', V_imgs)
print('total number of train and test picts:    ', V_train_imgs + V_test_imgs)
# Out:
# number of V images at the original file:  5696
# total number of train and test picts:     7122

# %%
Q_imgs       = len(os.listdir('ecg_img/train/Q/Q/'))
Q_train_imgs = len(os.listdir('ecg_img/train/Q/Q/'))
Q_test_imgs  = len(os.listdir('ecg_img/test/Q/Q/'))
print('number of Q images at the original file: ', Q_imgs)
print('total number of train and test picts:    ', Q_train_imgs + Q_test_imgs)
# Out:
# number of Q images at the original file:  26
# total number of train and test picts:     33

# %% [markdown]
# Lets load images with datasets.ImageFolder function and than read and plot

# %% [markdown]
# Set Data Loader

# %%
TRAIN_PATH        = 'ecg_img/train/'

transform         = transforms.Compose(
                                       [transforms.Resize([120,120]),
                                        transforms.Grayscale(), 
                                        transforms.ToTensor(),
                                        transforms.Normalize((0.5), (0.5))
                                       ])
  
train_data_set    = datasets.ImageFolder(root=TRAIN_PATH, transform=transform)

batch_size=32

train_data_loader = DataLoader(train_data_set, batch_size=batch_size, shuffle=True)

# %%
TEST_PATH        = 'ecg_img/test/'
  
test_data_set    = datasets.ImageFolder(root=TEST_PATH, transform=transform)

test_data_loader = DataLoader(test_data_set, batch_size=batch_size, shuffle=True)

# %%
# Run this to test your data loader

images, labels = next(iter(train_data_loader))

# %%
print(type(images))

print(images.size())

print("")
print("Batch Size:   ",images.size()[0])
print("Channel Size: ",images.size()[1])
print("Image Height: ",images.size()[2])
print("Image Width:  ",images.size()[3])
# Out:
# <class 'torch.Tensor'>
# torch.Size([32, 1, 120, 120])
#
# Batch Size:    32
# Channel Size:  1
# Image Height:  120
# Image Width:   120

# %% [markdown]
# The batch size is 32, image size is reduced to 120*120 and we need only one channel(Gray Scale).

# %%
def imshow_tensor(image, ax=None, title=None, normalize=True):
    
    """Imshow for Tensor."""
    
    if ax is None:
        fig, ax = plt.subplots()
        
    image = image.numpy().transpose((1, 2, 0))

    if normalize:
        mean = np.array([0.5])
        std = np.array([0.5])
        image = std * image + mean
        image = np.clip(image, 0, 1)

    ax.imshow(image)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    
    ax.tick_params(axis='both', length=0)
    ax.set_xticklabels('')
    ax.set_yticklabels('')

    return ax

# %% [markdown]
# Plot one Batch of Files from Dataloader

# %%
# show images

ncol = 8;

imshow_tensor(torchvision.utils.make_grid(images,nrow = ncol));

# %%
# print labels

classes = ('N', 'Q', 'F', 'S', 'V')

nrow = batch_size/ncol;

for row in range(int(nrow)):
    
    print(' '.join('%5s' % classes[labels[(row*ncol)+j]] for j in range(ncol)))
# Out:
#     Q     V     Q     V     Q     V     Q     V
#     V     V     F     Q     F     Q     Q     Q
#     Q     Q     N     V     Q     S     Q     Q
#     Q     Q     F     F     Q     S     Q     Q

# %% [markdown]
# Building Convolutional Neural Networks

# %% [markdown]
# First CNN Model

# %%
# CNN Architect

class ConvNet_1(nn.Module):
    
    def __init__(self):
        
        super(ConvNet_1, self).__init__()

        self.layer_1  = nn.Conv2d(in_channels=1, out_channels=4, kernel_size=3, stride=1, padding=1)
        
        self.relu1    = nn.ReLU(inplace=True)
        
        self.maxpool1 = MaxPool2d(kernel_size=2)
        

        self.layer_2  = nn.Conv2d(in_channels=4, out_channels=4, kernel_size=3, stride=1, padding=1)
        
        self.relu2    = nn.ReLU(inplace=True)
        
        self.maxpool2 = MaxPool2d(kernel_size=2)
        
        self.drop_out = nn.Dropout()
        
        
        # out_channels = 4, number of classes = 5
        
        # image width = 120, image height = 120 after two maxpooling 120 -> 60 -> 30
        
        self.fc1 = nn.Linear(4 * 30 * 30, 5)
        
    # Defining the forward pass
    def forward(self, x):
        
        out = self.layer_1(x)
        
        out = self.relu1(out)
        
        out = self.maxpool1(out)
        
        
        out = self.layer_2(out)
        
        out = self.relu2(out)
        
        out = self.maxpool2(out)
        
        
        out = out.reshape(out.size(0), -1)
        
        out = self.drop_out(out)
        
        out = self.fc1(out)
        
        return out
    
# Define Model

model_1 = ConvNet_1()

print(model_1)
# Out:
# ConvNet_1(
#   (layer_1): Conv2d(1, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu1): ReLU(inplace=True)
#   (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (layer_2): Conv2d(4, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu2): ReLU(inplace=True)
#   (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (drop_out): Dropout(p=0.5, inplace=False)
#   (fc1): Linear(in_features=3600, out_features=5, bias=True)
# )

# %%
# Define Criterion

criterion = nn.CrossEntropyLoss()

# Define Optimizer

optimizer = optim.SGD(model_1.parameters(), lr=0.001, momentum=0.9)

# %%
# Whether to train on a gpu and Number of gpus

if cuda.is_available(): 
    
    print(f'{cuda.device_count()} number of gpus are detected and available.')
    
else:
        
    print(f'Train on gpu is not available')
# Out:
# Train on gpu is not available

# %% [markdown]
# Train Our First Model

# %%
# This part is working

# Train the model

if torch.cuda.is_available():
    
    MODEL = model_1.cuda()
    CRITERION = criterion.cuda()
    print(f'Model is started training on {cuda.device_count()} number of gpus.')
    print("Devise is cuda")
    
else:
    
    MODEL = model_1
    CRITERION = criterion
    print("Devise is cpu and model is started training.")

total_step = len(train_data_loader)
loss_list = []
acc_list = []

num_epochs = 1

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

all_con_mat = torch.zeros([num_epochs, 5, 5], dtype=torch.int32, device=device)

for epoch in range(num_epochs):
     # define empty tensor 5*5 beginning of every epoch
    # tensor [row,column]
    con_mat = torch.zeros([5, 5], dtype=torch.int32, device=device)
    
    for i, data in enumerate(train_data_loader):
        
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        
        # optimization
        optimizer.zero_grad()
        
        # Forward to get output
        outputs = MODEL(inputs)
        # Calculate Loss
        loss = CRITERION(outputs, labels)
        # Backward propagation
        loss.backward()
        # Updating parameters
        optimizer.step()
        
        # Store loss
        loss_list.append(loss.item())
    
        # Calculate labels size
        total = labels.size(0)
        
        # Outputs.data has dimension batch size * 5
        # torch.max returns the max value of elements(_) and their indices(predicted) in the tensor array
        _, predicted = torch.max(outputs.data, 1)
         # Calculate total number of correct labels 
        correct = (predicted == labels).sum().item()
        
        # Store accuracy
        acc_list.append(correct / total)
        
        
        # Build Confusion Matrix
        for element in range(total):
            
            # con_mat[row,column]
            # con_mat[predictions, actual]
            
            con_mat[predicted[element].item()-1][labels[element].item()-1] += 1

        if (i + 1) % 300 == 0:                             # every 300 mini-batches...
            
            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Accuracy: {:.2f}%'
                  
                  .format(epoch + 1, num_epochs, i + 1, total_step, loss.item(),
                          (correct / total) * 100))
    print(con_mat)
            
    all_con_mat[epoch] = con_mat            
            
print('Finished Training')

plt.plot(loss_list);
plt.show();

plt.plot(acc_list);
plt.show();
# Out:
# Devise is cpu and model is started training.
# Epoch [1/1], Step [300/1162], Loss: 0.8473, Accuracy: 71.88%
# Epoch [1/1], Step [600/1162], Loss: 0.4826, Accuracy: 81.25%
# Epoch [1/1], Step [900/1162], Loss: 0.4721, Accuracy: 87.50%
# tensor([[21723,  2786,   859,  2782,   536],
#         [   79,  3514,    75,    68,     5],
#         [   17,     4,  1185,    15,     2],
#         [  277,   101,   100,  2911,    68],
#         [   26,     8,     3,     4,    30]], dtype=torch.int32)
# Finished Training

# %%
# SUM FOR EACH COLUMN

# N Q S V F

print(torch.sum(con_mat, dim=0))
# Out:
# tensor([22122,  6413,  2222,  5780,   641])

# %%
folder = 'ecg_img/'
list_files(folder)
# Out:
#  - 2
# test - 5
#     F - 1
#         F - 161
#     N - 5
#         e - 4
#         j - 46
#         L - 1614
#         N - 10545
#         R - 1452
#     Q - 3
#         f - 197
#         p - 1404
#         Q - 7
#     S - 4
#         A - 530
#         aa - 9
#         J - 17
#         S - 1
#     V - 2
#         E - 22
#         V - 1426
# train - 5
#     F - 1
#         F - 641
#     N - 5
#         e - 12
#         j - 183
#         L - 6454
#         N - 9676
#         R - 5797
#     Q - 3
#         f - 785
#         p - 5602
#         Q - 26
#     S - 4
#         A - 2035
#         aa - 120
#         J - 66
#         S - 1
#     V - 2
#         E - 84
#         V - 5696

# %%
# RECALL

# PRECISION

# F1-score = 2 × (precision × recall)/(precision + recall)

class_list = ['N', 'Q', 'S', 'V', 'F']

f1_score_list=[0,0,0,0,0]

precision_list=[0,0,0,0,0]

recall_list=[0,0,0,0,0]

delta = 0.0000000000001

for i in range(torch.sum(con_mat, dim=0).size(0)): 
    
    recall_list[i] = con_mat[i][i].item()/(torch.sum(con_mat, dim=0)[i].item()+delta)
    
    precision_list[i] = con_mat[i][i].item()/(torch.sum(con_mat, dim=1)[i].item()+delta)
    
    f1_score_list[i] = 2 * precision_list[i]*recall_list[i]/(precision_list[i]+recall_list[i]+delta)
    
    print('class: {:<2},total number of class: {:>5}, Correctly predicted: {:>5}, Recall: {:.2f}%, Precision: {:.2f}%, F1-Score: {:.2f}%'
          
                  .format(class_list[i],
                          torch.sum(con_mat, dim=0)[i].item(),
                          con_mat[i][i].item(), 
                          recall_list[i],
                          precision_list[i],
                          f1_score_list[i]
                         ))
# Out:
# class: N ,total number of class: 22122, Correctly predicted: 21723, Recall: 0.98%, Precision: 0.76%, F1-Score: 0.86%
# class: Q ,total number of class:  6413, Correctly predicted:  3514, Recall: 0.55%, Precision: 0.94%, F1-Score: 0.69%
# class: S ,total number of class:  2222, Correctly predicted:  1185, Recall: 0.53%, Precision: 0.97%, F1-Score: 0.69%
# class: V ,total number of class:  5780, Correctly predicted:  2911, Recall: 0.50%, Precision: 0.84%, F1-Score: 0.63%
# class: F ,total number of class:   641, Correctly predicted:    30, Recall: 0.05%, Precision: 0.42%, F1-Score: 0.08%

# %%
# This part is working

if torch.cuda.is_available():
    
    MODEL = model_1.cuda()
    CRITERION = criterion.cuda()
    print("cuda")
    
else:
    
    MODEL = model_1
    CRITERION = criterion
    print("cpu")

# Train the model

total_step = len(train_data_loader)
loss_list = []
acc_list = []

num_epochs = 5

class_list = ['N', 'Q', 'S', 'V', 'F']

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

all_con_mat = torch.zeros([num_epochs, 5, 5], dtype=torch.int32, device=device)

for epoch in range(num_epochs):
    f1_score_list=[0,0,0,0,0]

    precision_list=[0,0,0,0,0]

    recall_list=[0,0,0,0,0]
    
    delta = 0.0000000000001 
    
    # define empty tensor 5*5 beginning of every epoch
    # tensor [row,column]
    con_mat = torch.zeros([5, 5], dtype=torch.int32, device=device)
    
    for i, data in enumerate(train_data_loader):
        
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        
        # optimization
        optimizer.zero_grad()
        
        # Forward to get output
        outputs = MODEL(inputs)
        # Calculate Loss
        loss = CRITERION(outputs, labels)
        # Backward propagation
        loss.backward()
        # Updating parameters
        optimizer.step()
        
        # Store loss
        loss_list.append(loss.item())
    
        # Calculate labels size
        total = labels.size(0)
        
        # Outputs.data has dimension batch size * 5
        # torch.max returns the max value of elements(_) and their indices(predicted) in the tensor array
        _, predicted = torch.max(outputs.data, 1)
        
        # Calculate total number of correct labels 
        correct = (predicted == labels).sum().item()
        
        # Store accuracy
        acc_list.append(correct / total)
        
        for element in range(total):
            
            # con_mat[row,column]
            # con_mat[predictions, actual]
            con_mat[predicted[element].item()-1][labels[element].item()-1] += 1

        if (i + 1) % 300 == 0:                             # every 300 mini-batches...
            
            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Accuracy: {:.2f}%'
                  
                  .format(epoch + 1, num_epochs, i + 1, total_step, loss.item(),
                          (correct / total) * 100))
    print(con_mat)
            
    all_con_mat[epoch] = con_mat
    
    # Print Confusion Matrix
    
    for i in range(torch.sum(con_mat, dim=0).size(0)): 
    
        recall_list[i] = con_mat[i][i].item()/(torch.sum(con_mat, dim=0)[i].item()+delta)
    
        precision_list[i] = con_mat[i][i].item()/(torch.sum(con_mat, dim=1)[i].item()+delta)
    
        f1_score_list[i] = 2 * precision_list[i]*recall_list[i]/(precision_list[i]+recall_list[i]+delta)
        
    
        print('class name: {}, total number of class: {:>5}, Correctly predicted: {:>5}, Recall: {:.2f}%, Precision: {:.2f}%, F1-Score: {:.2f}%'
          
                  .format(class_list[i],
                          torch.sum(con_mat, dim=0)[i].item(),
                          con_mat[i][i].item(), 
                          recall_list[i],
                          precision_list[i],
                          f1_score_list[i]
                         ))
        
print('Finished Training')

plt.plot(loss_list);
plt.show();

plt.plot(acc_list);
plt.show();
# Out:
# cpu
# Epoch [1/5], Step [300/1162], Loss: 0.1404, Accuracy: 93.75%
# Epoch [1/5], Step [600/1162], Loss: 0.1846, Accuracy: 90.62%
# Epoch [1/5], Step [900/1162], Loss: 0.1205, Accuracy: 93.75%
# tensor([[21644,   363,   148,   636,   231],
#         [  139,  5902,     1,    97,     8],
#         [   25,    22,  2043,    19,     2],
#         [  288,   125,    30,  4985,   119],
#         [   26,     1,     0,    43,   281]], dtype=torch.int32)
# class name: N, total number of class: 22122, Correctly predicted: 21644, Recall: 0.98%, Precision: 0.94%, F1-Score: 0.96%
# class name: Q, total number of class:  6413, Correctly predicted:  5902, Recall: 0.92%, Precision: 0.96%, F1-Score: 0.94%
# class name: S, total number of class:  2222, Correctly predicted:  2043, Recall: 0.92%, Precision: 0.97%, F1-Score: 0.94%
# class name: V, total number of class:  5780, Correctly predicted:  4985, Recall: 0.86%, Precision: 0.90%, F1-Score: 0.88%
# class name: F, total number of class:   641, Correctly predicted:   281, Recall: 0.44%, Precision: 0.80%, F1-Score: 0.57%
# Epoch [2/5], Step [300/1162], Loss: 0.0406, Accuracy: 100.00%
# Epoch [2/5], Step [600/1162], Loss: 0.3487, Accuracy: 87.50%
# Epoch [2/5], Step [900/1162], Loss: 0.1968, Accuracy: 90.62%
# tensor([[21677,   283,    86,   551,   188],
#         [  126,  6036,     2,    75,     4],
#         [   13,    15,  2115,    12,     4],
#         [  270,    76,    19,  5093,    97],
#         [   36,     3,     0,    49,   348]], dtype=torch.int32)
# class name: N, total number of class: 22122, Correctly predicted: 21677, Recall: 0.98%, Precision: 0.95%, F1-Score: 0.97%
# class name: Q, total number of class:  6413, Correctly predicted:  6036, Recall: 0.94%, Precision: 0.97%, F1-Score: 0.95%
# class name: S, total number of class:  2222, Correctly predicted:  2115, Recall: 0.95%, Precision: 0.98%, F1-Score: 0.97%
# class name: V, total number of class:  5780, Correctly predicted:  5093, Recall: 0.88%, Precision: 0.92%, F1-Score: 0.90%
# class name: F, total number of class:   641, Correctly predicted:   348, Recall: 0.54%, Precision: 0.80%, F1-Score: 0.65%
# Epoch [3/5], Step [300/1162], Loss: 0.1358, Accuracy: 96.88%
# Epoch [3/5], Step [600/1162], Loss: 0.2024, Accuracy: 93.75%
# Epoch [3/5], Step [900/1162], Loss: 0.0171, Accuracy: 100.00%
# tensor([[21697,   242,    48,   504,   163],
#         [  113,  6078,     2,    63,     4],
#         [   11,    15,  2153,     6,     2],
#         [  263,    75,    18,  5155,    89],
#         [   38,     3,     1,    52,   383]], dtype=torch.int32)
# class name: N, total number of class: 22122, Correctly predicted: 21697, Recall: 0.98%, Precision: 0.96%, F1-Score: 0.97%
# class name: Q, total number of class:  6413, Correctly predicted:  6078, Recall: 0.95%, Precision: 0.97%, F1-Score: 0.96%
# class name: S, total number of class:  2222, Correctly predicted:  2153, Recall: 0.97%, Precision: 0.98%, F1-Score: 0.98%
# class name: V, total number of class:  5780, Correctly predicted:  5155, Recall: 0.89%, Precision: 0.92%, F1-Score: 0.91%
# class name: F, total number of class:   641, Correctly predicted:   383, Recall: 0.60%, Precision: 0.80%, F1-Score: 0.69%
# Epoch [4/5], Step [300/1162], Loss: 0.0379, Accuracy: 100.00%
# Epoch [4/5], Step [600/1162], Loss: 0.2851, Accuracy: 87.50%
# Epoch [4/5], Step [900/1162], Loss: 0.1047, Accuracy: 93.75%
# tensor([[21716,   221,    48,   478,   160],
#         [  114,  6108,     1,    46,     7],
#         [   10,     9,  2165,     6,     1],
#         [  232,    72,     7,  5208,    82],
#         [   50,     3,     1,    42,   391]], dtype=torch.int32)
# class name: N, total number of class: 22122, Correctly predicted: 21716, Recall: 0.98%, Precision: 0.96%, F1-Score: 0.97%
# class name: Q, total number of class:  6413, Correctly predicted:  6108, Recall: 0.95%, Precision: 0.97%, F1-Score: 0.96%
# class name: S, total number of class:  2222, Correctly predicted:  2165, Recall: 0.97%, Precision: 0.99%, F1-Score: 0.98%
# class name: V, total number of class:  5780, Correctly predicted:  5208, Recall: 0.90%, Precision: 0.93%, F1-Score: 0.92%
# class name: F, total number of class:   641, Correctly predicted:   391, Recall: 0.61%, Precision: 0.80%, F1-Score: 0.69%
# Epoch [5/5], Step [300/1162], Loss: 0.0709, Accuracy: 100.00%
# Epoch [5/5], Step [600/1162], Loss: 0.1180, Accuracy: 93.75%
# Epoch [5/5], Step [900/1162], Loss: 0.0472, Accuracy: 100.00%
# tensor([[21744,   199,    45,   472,   155],
#         [  103,  6146,     0,    50,     4],
#         [    8,     8,  2168,     5,     1],
#         [  223,    57,     9,  5198,    81],
#         [   44,     3,     0,    55,   400]], dtype=torch.int32)
# class name: N, total number of class: 22122, Correctly predicted: 21744, Recall: 0.98%, Precision: 0.96%, F1-Score: 0.97%
# class name: Q, total number of class:  6413, Correctly predicted:  6146, Recall: 0.96%, Precision: 0.98%, F1-Score: 0.97%
# class name: S, total number of class:  2222, Correctly predicted:  2168, Recall: 0.98%, Precision: 0.99%, F1-Score: 0.98%
# class name: V, total number of class:  5780, Correctly predicted:  5198, Recall: 0.90%, Precision: 0.93%, F1-Score: 0.92%
# class name: F, total number of class:   641, Correctly predicted:   400, Recall: 0.62%, Precision: 0.80%, F1-Score: 0.70%
# Finished Training

# %%
all_con_mat
# Out:
# tensor([[[21644,   363,   148,   636,   231],
#          [  139,  5902,     1,    97,     8],
#          [   25,    22,  2043,    19,     2],
#          [  288,   125,    30,  4985,   119],
#          [   26,     1,     0,    43,   281]],
#
#         [[21677,   283,    86,   551,   188],
#          [  126,  6036,     2,    75,     4],
#          [   13,    15,  2115,    12,     4],
#          [  270,    76,    19,  5093,    97],
#          [   36,     3,     0,    49,   348]],
#
#         [[21697,   242,    48,   504,   163],
#          [  113,  6078,     2,    63,     4],
#          [   11,    15,  2153,     6,     2],
#          [  263,    75,    18,  5155,    89],
#          [   38,     3,     1,    52,   383]],
#
#         [[21716,   221,    48,   478,   160],
#          [  114,  6108,     1,    46,     7],
#          [   10,     9,  2165,     6,     1],
#          [  232,    72,     7,  5208,    82],
#          [   50,     3,     1,    42,   391]],
#
#         [[21744,   199,    45,   472,   155],
#          [  103,  6146,     0,    50,     4],
#          [    8,     8,  2168,     5,     1],
#          [  223,    57,     9,  5198,    81],
#          [   44,     3,     0,    55,   400]]], dtype=torch.int32)

# %% [markdown]
# Check Trained 1. Model on the Test Data

# %%
confusion_mat = torch.zeros([5, 5], dtype=torch.int32, device=device)

with torch.no_grad():
    
    for data in test_data_loader:
        
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        
        outputs = MODEL(inputs)
        
        _, predicted = torch.max(outputs.data, 1)
        
        total = labels.size(0)
        
        # Calculate total number of correct labels 
        correct = (predicted == labels).sum().item()
        
        for element in range(total):
            
            # confusion_mat[row,column]
            # confusion_mat[predictions, actual]
            confusion_mat[predicted[element].item()-1][labels[element].item()-1] += 1

    print(confusion_mat)
# Out:
# tensor([[12248,    68,    17,   124,    38],
#         [  159,  1526,     0,    12,     0],
#         [   12,     0,   537,     0,     1],
#         [  308,    13,     3,  1299,    20],
#         [  934,     1,     0,    13,   102]], dtype=torch.int32)

# %%
class_list = ['N', 'Q', 'S', 'V', 'F']

f1_score_list=[0,0,0,0,0]

precision_list=[0,0,0,0,0]

recall_list=[0,0,0,0,0]
    
delta = 0.0000000000001 


for i in range(torch.sum(confusion_mat, dim=0).size(0)): 
    
        recall_list[i] = confusion_mat[i][i].item()/(torch.sum(confusion_mat, dim=0)[i].item()+delta)
    
        precision_list[i] = confusion_mat[i][i].item()/(torch.sum(confusion_mat, dim=1)[i].item()+delta)
    
        f1_score_list[i] = 2 * precision_list[i]*recall_list[i]/(precision_list[i]+recall_list[i]+delta)
        
        print('class name: {}, total number of class: {:>5}, Correctly predicted: {:>5}, Recall: {:.2f}%, Precision: {:.2f}%, F1-Score: {:.2f}%'
          
                  .format(class_list[i],
                          torch.sum(confusion_mat, dim=0)[i].item(),
                          confusion_mat[i][i].item(), 
                          recall_list[i],
                          precision_list[i],
                          f1_score_list[i]
                         ))
# Out:
# class name: N, total number of class: 13661, Correctly predicted: 12248, Recall: 0.90%, Precision: 0.98%, F1-Score: 0.94%
# class name: Q, total number of class:  1608, Correctly predicted:  1526, Recall: 0.95%, Precision: 0.90%, F1-Score: 0.92%
# class name: S, total number of class:   557, Correctly predicted:   537, Recall: 0.96%, Precision: 0.98%, F1-Score: 0.97%
# class name: V, total number of class:  1448, Correctly predicted:  1299, Recall: 0.90%, Precision: 0.79%, F1-Score: 0.84%
# class name: F, total number of class:   161, Correctly predicted:   102, Recall: 0.63%, Precision: 0.10%, F1-Score: 0.17%
